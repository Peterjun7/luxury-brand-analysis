# %%
#csv로 파일변환
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

xlsx = pd.read_excel("/Users/im/Desktop/STUDY/DS/DS_PROJECT/hermes_address.xlsx")
xlsx.to_csv("/Users/im/Desktop/STUDY/DS/DS_PROJECT/hermes_address.csv")

# %%
xlsx2 = pd.read_excel("/Users/im/Desktop/STUDY/DS/DS_PROJECT/louis_vuitton_address.xlsx")
xlsx2.to_csv("/Users/im/Desktop/STUDY/DS/DS_PROJECT/louis_vuitton_address.csv")

# %%
xlsx3 = pd.read_excel("/Users/im/Desktop/STUDY/DS/DS_PROJECT/chanel_address.xlsx")
xlsx3.to_csv("/Users/im/Desktop/STUDY/DS/DS_PROJECT/chanel_address.csv")

# %%
xlsx4 = pd.read_excel("/Users/im/Desktop/STUDY/DS/DS_PROJECT/christian_dior_address.xlsx")
xlsx4.to_csv("/Users/im/Desktop/STUDY/DS/DS_PROJECT/christian_dior_address.csv")
